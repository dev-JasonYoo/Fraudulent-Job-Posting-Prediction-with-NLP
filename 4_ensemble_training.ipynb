# %% [markdown]
# # ensemble learning
# ## voting method

# %%
import pickle
from sklearn.ensemble import VotingClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
models_dict = {
    'model_dt': DecisionTreeClassifier(),
    'model_lr': LogisticRegression(),
    'model_rf': RandomForestClassifier(),
    'model_svm': SVC(),
    'model_xgb': XGBClassifier()
}

path_dict = {
    'model_dt': 'decision_tree_model.pkl',
    'model_lr': 'logistic_regression_model.pkl',
    'model_rf': 'rf_model.pkl',
    'model_svm': 'svm_model.pkl',
    'model_xgb': 'xgboost_model.pkl'
}

# load all models
for model_name, model in models_dict.items():
    with open(path_dict[model_name], 'wb') as saved_model:
        pickle.dump(models_dict[model_name], saved_model)

# %%
voting_model = VotingClassifier(
    estimators=[(model_name, models_dict[model_name]) for model_name in ['model_dt', 'model_svm', 'model_xgb']],
    voting='soft'
)

# voting_model.fit(X_train, y_train)
pred_voting = voting_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       1 voting_model = VotingClassifier(
#       2     estimators=[(model_name, models_dict[model_name]) for model_name in ['model_dt', 'model_svm', 'model_xgb']],
#       3     voting='soft'
#       4 )
#       6 # voting_model.fit(X_train, y_train)
# ----> 7 pred_voting = voting_model.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
print(f"Voting Classifier F2 score:   {fbeta_score(y_test, pred_voting, beta=2, average='binary'):.4f}")
# Out:
# Voting Classifier F2 score:   0.5575

# %% [markdown]
# ## Stacking classifier
# Need to train it from scratch?
